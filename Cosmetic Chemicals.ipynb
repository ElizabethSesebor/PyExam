# %%
import pandas as pd
import requests as r
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
data= ('C:\\Users\Layefa\Dropbox\PC\Documents\Project Datasets\chemicals-in-cosmetics-.csv')
df= pd.read_csv(data)

# %%
df
# Out:
#          index  CDPHId                                        ProductName  \
# 0            0       2   ULTRA COLOR RICH EXTRA PLUMP LIPSTICK-ALL SHADES
# 1            1       3                         Glover's Medicated Shampoo
# 2            2       3                         Glover's Medicated Shampoo
# 3            3       4           PRECISION GLIMMER EYE LINER-ALL SHADES �
# 4            4       5        AVON BRILLIANT SHINE LIP GLOSS-ALL SHADES �
# ...        ...     ...                                                ...
# 114293  114293   41445  JILLSTUART Something Pure Blue Diamond Glaze L...
# 114294  114294   41446             JILLSTUART something pure blue my lips
# 114295  114295   41449             SPRING BLOSSOM VANILLA APPLE BODY WASH
# 114296  114296   41450                 Wild Breeze Water Lilies Hand Soap
# 114297  114297   41451                         BEVEL EXFOLIATING BAR SOAP
#
#         CSFId  CSF  CompanyId                  Company Name   Brand Name  \
# ...

# %%
df.dtypes
# Out:
# index                       int64
# CDPHId                      int64
# ProductName                object
# CSFId                     float64
# CSF                        object
# CompanyId                   int64
# Company Name               object
# Brand Name                 object
# PrimaryCategoryId           int64
# Primary Category           object
# SubCategoryId               int64
# Sub Category               object
# CasId                       int64
# CasNumber                  object
# ChemicalId                  int64
# Chemical Name              object
# InitialDateReported         int64
# MostRecentDateReported      int64
# Discontinued Date         float64
# ChemicalCreatedAt           int64
# ChemicalUpdatedAt           int64
# ChemicalDateRemoved       float64
# Chemical Count              int64
# dtype: object

# %%
df.shape
# Out:
# (114298, 23)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 114298 entries, 0 to 114297
# Data columns (total 23 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   index                   114298 non-null  int64
#  1   CDPHId                  114298 non-null  int64
#  2   ProductName             114298 non-null  object
#  3   CSFId                   80382 non-null   float64
#  4   CSF                     79958 non-null   object
#  5   CompanyId               114298 non-null  int64
#  6   Company Name            114298 non-null  object
#  7   Brand Name              114082 non-null  object
#  8   PrimaryCategoryId       114298 non-null  int64
#  9   Primary Category        114298 non-null  object
#  10  SubCategoryId           114298 non-null  int64
#  11  Sub Category            114298 non-null  object
#  12  CasId                   114298 non-null  int64
#  13  CasNumber               107902 non-null  object
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# index                          0
# CDPHId                         0
# ProductName                    0
# CSFId                      33916
# CSF                        34340
# CompanyId                      0
# Company Name                   0
# Brand Name                   216
# PrimaryCategoryId              0
# Primary Category               0
# SubCategoryId                  0
# Sub Category                   0
# CasId                          0
# CasNumber                   6396
# ChemicalId                     0
# Chemical Name                  0
# InitialDateReported            0
# MostRecentDateReported         0
# Discontinued Date         101390
# ChemicalCreatedAt              0
# ChemicalUpdatedAt              0
# ChemicalDateRemoved       111325
# Chemical Count                 0
# dtype: int64

# %%
df.fillna(0, inplace=True)

# %%
df.head()
# Out:
#    index  CDPHId                                       ProductName  CSFId CSF  \
# 0      0       2  ULTRA COLOR RICH EXTRA PLUMP LIPSTICK-ALL SHADES    0.0   0
# 1      1       3                        Glover's Medicated Shampoo    0.0   0
# 2      2       3                        Glover's Medicated Shampoo    0.0   0
# 3      3       4          PRECISION GLIMMER EYE LINER-ALL SHADES �    0.0   0
# 4      4       5       AVON BRILLIANT SHINE LIP GLOSS-ALL SHADES �    0.0   0
#
#    CompanyId         Company Name Brand Name  PrimaryCategoryId  \
# 0          4         New Avon LLC       AVON                 44
# 1        338  J. Strickland & Co.   Glover's                 18
# 2        338  J. Strickland & Co.   Glover's                 18
# 3          4         New Avon LLC       AVON                 44
# 4          4         New Avon LLC       AVON                 44
#
#                     Primary Category  ...   CasNumber ChemicalId  \
# ...

# %%
df['ProductName'].to_frame()
# Out:
#                                               ProductName
# 0        ULTRA COLOR RICH EXTRA PLUMP LIPSTICK-ALL SHADES
# 1                              Glover's Medicated Shampoo
# 2                              Glover's Medicated Shampoo
# 3                PRECISION GLIMMER EYE LINER-ALL SHADES �
# 4             AVON BRILLIANT SHINE LIP GLOSS-ALL SHADES �
# ...                                                   ...
# 114293  JILLSTUART Something Pure Blue Diamond Glaze L...
# 114294             JILLSTUART something pure blue my lips
# 114295             SPRING BLOSSOM VANILLA APPLE BODY WASH
# 114296                 Wild Breeze Water Lilies Hand Soap
# 114297                         BEVEL EXFOLIATING BAR SOAP
#
# [114298 rows x 1 columns]

# %%
df['Chemical Name'].to_frame()
# Out:
#                  Chemical Name
# 0             Titanium dioxide
# 1       Distillates (coal tar)
# 2                    Estragole
# 3             Titanium dioxide
# 4             Titanium dioxide
# ...                        ...
# 114293        Titanium dioxide
# 114294        Titanium dioxide
# 114295            Cocamide DEA
# 114296            Cocamide DEA
# 114297        Titanium dioxide
#
# [114298 rows x 1 columns]

# %%
df.loc[df['ProductName'] == "Nail Lacquer", 'Chemical Name'].unique()
# Out:
# array(['Titanium dioxide',
#        'Isopropyl alcohol manufacture using strong acids',
#        'Silica, crystalline (airborne particles of respirable size)',
#        'Mica', 'Carbon black'], dtype=object)

# %%
# Number of Chemicals in each products

# %%
df.groupby(['ProductName'])['Chemical Count'].unique().to_frame()
# Out:
#                                                    Chemical Count
# ProductName
# " ROUGE DIOR ULTRA CARE LIQUID Flower Oil Liqui...            [1]
# "DIOR PRESTIGE LE MICRO-FLUIDE TEINT DE ROSE Mi...            [1]
# "Hello Flawless!" SPF 15                                      [1]
# "I'm Glam...Therefore I Am" -Glamming Powder I                [1]
# "My dream lather" Soap 'Bar                                   [1]
# ...                                                           ...
# watermelon brightening mask                                   [1]
# waterproof shadow stick                                       [1]
# winter wish list eye set palette                              [1]
# winter wonderglam luxe eye palette                            [1]
# young, wild & free Amazonian clay palette                     [1]
#
# [33638 rows x 1 columns]

# %%
df.loc[df.ProductName == 'BEVEL EXFOLIATING BAR SOAP', 'Chemical Name']
# Out:
# 114297    Titanium dioxide
# Name: Chemical Name, dtype: object

# %%
# Plotting chemical count against product name

# %%
fig, ax = plt.subplots(figsize= (20, 10))
plt.xticks(rotation= 90)
sns.barplot(x= 'ProductName', y= 'Chemical Count', data= df,
             order = df['ProductName'].value_counts().iloc[:50].index)
plt.title('Number of Chemicals Present in a Product')
plt.ylabel('Chemical Count')
plt.xlabel('ProductName')
# Out:
# Text(0.5, 0, 'ProductName')

# %%
# Chemicals used in different categories of products

# %%
df.groupby(['Primary Category'])['Chemical Name'].unique().to_frame()
# Out:
#                                                                        Chemical Name
# Primary Category
# Baby Products                      [Trade Secret, Cocamide diethanolamine, Styren...
# Bath Products                      [Cocamide diethanolamine, Titanium dioxide, Ch...
# Fragrances                         [Titanium dioxide, Estragole, Acetaldehyde, Bu...
# Hair Care Products (non-coloring)  [Distillates (coal tar), Estragole, Cocamide d...
# Hair Coloring Products             [Titanium dioxide, o-Phenylphenol, Lead acetat...
# Makeup Products (non-permanent)    [Titanium dioxide, Retinol/retinyl esters, whe...
# Nail Products                      [Titanium dioxide, Toluene, Carbon black, Acry...
# Oral Hygiene Products              [Silica, crystalline (airborne particles of re...
# Personal Care Products             [Cocamide diethanolamine, Titanium dioxide, Mi...
# Shaving Products                   [Titanium dioxide, Butylated hydroxyanisole, R...
# ...

# %%
# Chemicals each companies use in different categories of products

# %%
df.groupby(['Primary Category', 'Chemical Name'])['Company Name'].unique().to_frame()
# Out:
#                                                                                                                       Company Name
# Primary Category             Chemical Name
# Baby Products                Acetaldehyde                                                                                   [Test]
#                              Butylated hydroxyanisole                                       [Johnson & Johnson Consumer Companies]
#                              Cadmium and cadmium compounds                                                    [Harmon Stores Inc.]
#                              Cocamide DEA                                                                       [Oceana USA, Inc.]
#                              Cocamide diethanolamine                             [Buth-na-Bodhaige, Inc, Delon Laboratories (19...
# ...                                                                                                                            ...
# ...
